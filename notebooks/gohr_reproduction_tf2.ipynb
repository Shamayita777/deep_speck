# %%
# !git clone https://github.com/Shamayita777/deep_speck.git
# Out:
# Cloning into 'deep_speck'...
# remote: Enumerating objects: 77, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 77 (delta 10), reused 8 (delta 8), pack-reused 57 (from 1)
# Receiving objects: 100% (77/77), 1.96 MiB | 27.55 MiB/s, done.
# Resolving deltas: 100% (20/20), done.

# %%
# %cd deep_speck
# Out:
# /content/deep_speck

# %%
# !pwd
# Out:
# /content/deep_speck

# %%
# !git branch
# Out:
# * master

# %%
# !git checkout -b reproduction-tf2
# Out:
# Switched to a new branch 'reproduction-tf2'

# %%
# !git branch
# Out:
#   master
# * reproduction-tf2

# %%
# !mkdir -p docs
# !touch docs/reproduction_log.md
# !touch docs/compatibility_changes.md

# %%
# !git status
# Out:
# On branch reproduction-tf2
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	docs/
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.20.0

# %%
import keras
print(keras.__version__)
# Out:
# 3.13.2

# %%
import sys
print(sys.version)
# Out:
# 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]

# %%
# !git config --global user.name "Shamayita777"
# !git config --global user.email "moitrashamayita@gmail.com"

# %%
# !git add docs
# !git commit -m "Initialize reproduction documentation"
# Out:
# [reproduction-tf2 54b056b] Initialize reproduction documentation
#  2 files changed, 0 insertions(+), 0 deletions(-)
#  create mode 100644 docs/compatibility_changes.md
#  create mode 100644 docs/reproduction_log.md

# %%
# !git tag reproduction-start

# %%
import speck as sp

sp.check_testvector()
# Out:
# Testvector verified.
# True

# %%
import train_nets as tn

# %%
tn.make_resnet()
# Out:
# <Functional name=functional, built=True>

# %%
import train_nets as tn

tn.train_speck_distinguisher(
    1,              # 1 epoch only
    num_rounds=5,
    depth=10
)
# Out:
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - acc: 0.8806 - loss: 0.0969
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 102s 39ms/step - acc: 0.9035 - loss: 0.0798 - val_acc: 0.9176 - val_loss: 0.0671 - learning_rate: 0.0020
# Best validation accuracy:  0.9176070094108582
# (<Functional name=functional_1, built=True>,
#  <keras.src.callbacks.history.History at 0x78e8269c1670>)

# %%
# !git add .
# !git commit -m "Verified training pipeline under TensorFlow 2.20 and Keras 3"
# Out:
# [reproduction-tf2 cdff5f9] Verified training pipeline under TensorFlow 2.20 and Keras 3
#  5 files changed, 0 insertions(+), 0 deletions(-)
#  create mode 100644 __pycache__/speck.cpython-312.pyc
#  create mode 100644 __pycache__/train_nets.cpython-312.pyc
#  create mode 100644 freshly_trained_nets/best5depth10.h5
#  create mode 100644 freshly_trained_nets/h5r_depth10.npy
#  create mode 100644 freshly_trained_nets/hist5r_depth10.p

# %%
import train_nets as tn

tn.train_speck_distinguisher(
    200,
    num_rounds=5,
    depth=10
)
# Out:
# Epoch 1/200
# 1999/2000 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - acc: 0.8807 - loss: 0.0964
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 100s 39ms/step - acc: 0.9039 - loss: 0.0794 - val_acc: 0.9183 - val_loss: 0.0669 - learning_rate: 0.0020
# Epoch 2/200
# 1999/2000 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - acc: 0.9201 - loss: 0.0648
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ...

# %%
# !git add.
# !git commit -m "Faithful reproduction of Gohr 5-round distinguisher"
# !git tag gohr-faithful-reproduction
