# %%
# !git clone https://github.com/Shamayita777/deep_speck.git
# Out:
# Cloning into 'deep_speck'...
# remote: Enumerating objects: 110, done.
# remote: Counting objects: 100% (52/52), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 110 (delta 16), reused 39 (delta 12), pack-reused 58 (from 1)
# Receiving objects: 100% (110/110), 3.50 MiB | 22.02 MiB/s, done.
# Resolving deltas: 100% (26/26), done.

# %%
# %cd deep_speck
# !git checkout audit-dataset-integrity
# Out:
# /content/deep_speck
# Branch 'audit-dataset-integrity' set up to track remote branch 'audit-dataset-integrity' from 'origin'.
# Switched to a new branch 'audit-dataset-integrity'

# %%
# !git branch
# Out:
# * audit-dataset-integrity
#   master

# %%
# !ls
# Out:
# audit				net5_small.h5
# cpp				net6_small.h5
# data_wrong_key_8r_mean_1e6.npy	net7_small.h5
# data_wrong_key_8r_std_1e6.npy	net8_small.h5
# data_wrong_key_mean_6r.npy	neural_difference_search.py
# data_wrong_key_mean_7r.npy	notebooks
# data_wrong_key_std_6r.npy	readme.md
# data_wrong_key_std_7r.npy	simple_net
# docs				single_block_resnet.json
# eval.py				speck.py
# freshly_trained_nets		supplementary_data
# key_averaging.py		test_key_recovery.py
# key_nonuniformity.py		train_5_rounds.py
# key_rank_ddt.py			train_nets.py
# key_rank.py

# %%
# !ls audit/dataset
# Out:
# d1_duplicate_detection.py  d3_distribution_statistics.py
# d2_leakage_detection.py

# %%
# !python -m audit.dataset.d1_duplicate_detection
# Out:
# Training samples   : 10000000
# Validation samples : 1000000
# ...
# Dataset Integrity Audit
# D1 – Duplicate Sample Detection
# ...
#
# Training duplicates          : 0
# Validation duplicates        : 0
#
# Train ↔ Validation overlap   : 0

# %%
# !git rev-parse HEAD
# Out:
# 65ca38f314672b3a7a2aee445c2e1df181ad4de5

# %%
# !git tag dataset-integrity-d1-v1
# !git push origin dataset-integrity-d1-v1
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address
