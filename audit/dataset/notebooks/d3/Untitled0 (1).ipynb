# %%
# !git clone https://github.com/Shamayita777/deep_speck.git
# Out:
# Cloning into 'deep_speck'...
# remote: Enumerating objects: 110, done.
# remote: Counting objects: 100% (52/52), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 110 (delta 16), reused 39 (delta 12), pack-reused 58 (from 1)
# Receiving objects: 100% (110/110), 3.50 MiB | 7.77 MiB/s, done.
# Resolving deltas: 100% (26/26), done.

# %%
# %cd deep_speck
# !git checkout audit-implementation-integrity
# Out:
# /content/deep_speck
# Branch 'audit-implementation-integrity' set up to track remote branch 'audit-implementation-integrity' from 'origin'.
# Switched to a new branch 'audit-implementation-integrity'

# %%
# !git config --global user.name "Shamayita777"
# !git config --global user.email "moitrashamayita@gmail.com"

# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import train_nets as tn

net, history = tn.train_speck_distinguisher(
    200,
    num_rounds=5,
    depth=10,
    seed=999
)
# Out:
# Epoch 1/200
# 1999/2000 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - acc: 0.8785 - loss: 0.0979
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 99s 38ms/step - acc: 0.9044 - loss: 0.0789 - val_acc: 0.9212 - val_loss: 0.0643 - learning_rate: 0.0020
# Epoch 2/200
# 1999/2000 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - acc: 0.9230 - loss: 0.0624
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ...

# %%
best_val_loss = min(history.history['val_loss'])
print(best_val_loss)
# Out:
# 0.05477297306060791

# %%
# !git add .
# !git commit -m "Add deterministic seed control for implementation integrity audit 4"
# Out:
# [audit-implementation-integrity dfcf4ac] Add deterministic seed control for implementation integrity audit 4
#  3 files changed, 0 insertions(+), 0 deletions(-)
#  rewrite freshly_trained_nets/best5depth10.h5 (64%)
#  rewrite freshly_trained_nets/h5r_depth10.npy (92%)
#  rewrite freshly_trained_nets/hist5r_depth10.p (100%)

# %%
# !git fetch origin
# !git branch
# !git checkout audit-dataset-integrity
# !git pull origin audit-dataset-integrity
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 5 (delta 2), reused 5 (delta 2), pack-reused 0 (from 0)
# Unpacking objects: 100% (5/5), 3.09 KiB | 1.54 MiB/s, done.
# From https://github.com/Shamayita777/deep_speck
#    65ca38f..a8e4fcb  audit-dataset-integrity -> origin/audit-dataset-integrity
# * audit-implementation-integrity
#   master
# Branch 'audit-dataset-integrity' set up to track remote branch 'audit-dataset-integrity' from 'origin'.
# Switched to a new branch 'audit-dataset-integrity'
# From https://github.com/Shamayita777/deep_speck
#  * branch            audit-dataset-integrity -> FETCH_HEAD
# Already up to date.

# %%
# !ls audit/dataset/
# Out:
# d1_duplicate_detection.py  d3_distribution_statistics.py
# d2_leakage_detection.py

# %%
# !python -m audit.dataset.d3_distribution_statistics
# Out:
# ...
# Dataset Integrity Audit
# D3 – Distribution Statistics
# ...
#
# Representation      : Binary
#
# Training
# ----------------------------------------
# Samples             : 10000000
# Positive Samples    : 4999261
# Negative Samples    : 5000739
# Positive Ratio      : 0.499926
# Negative Ratio      : 0.500074
# Feature Mean        : 0.499991
# Feature Variance    : 0.250000
# Bit Density         : 0.499991
# Average Entropy     : 1.000000
#
# Validation
# ----------------------------------------
# Samples             : 1000000
# Positive Samples    : 499984
# Negative Samples    : 500016
# Positive Ratio      : 0.499984
# Negative Ratio      : 0.500016
# Feature Mean        : 0.499926
# Feature Variance    : 0.250000
# Bit Density         : 0.499926
# Average Entropy     : 0.999999
#
# Consistency
# ----------------------------------------
# Class Ratio Diff    : 0.000058
# Feature Mean Diff   : 0.000066
# Variance Diff       : 0.000000
# Entropy Diff        : 0.000001
#
# ...

# %%
# !git status
# Out:
# On branch audit-dataset-integrity
# Your branch is up to date with 'origin/audit-dataset-integrity'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	d3_distribution_statistics.json
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git add d3_distribution_statistics.json

# %%
# !git commit -m "Implement Dataset Integrity Audit D3: Distribution Statistics"
# Out:
# [audit-dataset-integrity 5b5bcef] Implement Dataset Integrity Audit D3: Distribution Statistics
#  1 file changed, 304 insertions(+)
#  create mode 100644 d3_distribution_statistics.json

# %%
# !git tag dataset-integrity-d3-v1
